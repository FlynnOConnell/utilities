# %%
import masknmf
import roicat
# Out:
# W0827 16:08:13.975000 30708 Lib\site-packages\torch\utils\flop_counter.py:29] triton not found; flop counting will not work for triton kernels
# WARNING: The name 'coolwarm' is an alias for 'matplotlib:coolwarm', but is also available as: 'paraview:coolwarm'.
# To silence this warning, use a fully namespaced name.
